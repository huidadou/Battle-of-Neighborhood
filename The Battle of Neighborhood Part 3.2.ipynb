# %% [markdown]
# ### Intalling folium for map visualisation

# %%
# intalling folium
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 102kB 7.3MB/s ta 0:00:011
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np

# Nominatim converts an address into latitude and langitude values
from geopy.geocoders import Nominatim

# tranform JSON file into a pandas dataframe
from pandas.io.json import json_normalize

import requests
import json
from bs4 import BeautifulSoup

from pandas.io.json import json_normalize
print("all libraries have been imported");
# Out:
# all libraries have been imported

# %%
# read csv file
schinfo_df = pd.read_csv('DF5_Secondary Schools.csv')

# view
schinfo_df.head()
# Out:
#   Planning Area                                Name
# 0     Woodlands          Admiralty Secondary School
# 1        Yishun      Ahmad Ibrahim Secondary School
# 2    Ang Mo Kio           Anderson Secondary School
# 3         Bedok                Anglican High School
# 4        Newton  Anglo-Chinese School (Barker Road)

# %%
# check
schinfo_df.shape
# Out:
# (159, 2)

# %%
# create sets for replacement
old = ["Geylang Methodist School (Secondary)", "Methodist Girls' School (Secondary)", "Paya Lebar Methodist Girls' School (Secondary)" ,"Madrasah Aljunied Al-Islamiah"]
new = ["Geylang Methodist School", "Methodist Girls' School", "Paya Lebar Methodist Girls' School (Secondary)", "Madrasah Aljunied Al-Islamiah, SG"]

# change their values names to listed planning areas
schinfo_df["Name"] = schinfo_df["Name"].replace(old, new)

# %%
# Nominatim converts an address into latitude and langitude values
from geopy.geocoders import Nominatim

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(65):
    getLanlong(x)
# Out:
# 1.4459118499999999
# 1.4360948
# 1.37541705
# 1.33021825
# 1.3197093999999998
# 1.3029215
# 1.3676706
# 1.3690319
# 1.3406552
# 1.3417851
# 1.334061
# 1.3255597
# 1.32474105
# 1.3244863
# 1.3427581000000002
# 1.3708838499999998
# 1.30726495
# 1.3484109000000002
# 1.2859241
# 1.3820990499999999
# 1.3451218
# 30.4405309
# 1.45374325
# 1.3342195000000001
# 1.3404936
# 1.3060071
# 1.3326721
# 1.39185175
# 1.37344905
# 1.27614885
# 1.38350835
# 1.42666655
# 1.3053550999999999
# 1.41910045
# 1.31566085
# 1.31969715
# 1.39652095
# 1.2936354
# 1.337598
# 1.3667377
# 1.36358465
# 1.2987458
# 1.36116845
# 1.3569738500000001
# 1.4002065
# 1.44173915
# 1.30171935
# 1.3753080500000001
# 1.43072245
# 1.34730265
# 1.2894694000000002
# 1.3176038499999998
# 1.3977221499999999
# 1.3825375
# 1.34461375
# 1.3745734
# 1.3533675
# 1.3716598
# 1.3527114500000001
# 1.37773995
# 1.3520885
# 1.3262797499999999
# 1.3530906
# 1.33030995
# 1.3354612000000001

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(66,69):
    getLanlong(x)
# Out:
# 1.33825905
# 1.3011517000000001
# 1.3905569500000001

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(71,93):
    getLanlong(x)
# Out:
# 1.3275613499999999
# 1.3420098500000002
# 1.43729935
# 1.3686557
# 0.4670449
# 1.3328403500000001
# -8.68127525
# 1.3894693
# 1.3083036
# 1.3305083500000001
# 1.330727
# 1.4197322
# 1.30988355
# 1.3543069
# 1.3816673000000002
# 1.4212669
# 1.43571045
# 1.3069962
# 1.4157749499999999
# 1.28627625
# 1.37271
# 1.35470585

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(94,150):
    getLanlong(x)
# Out:
# 1.39088135
# 1.35891515
# 1.3664814
# 1.3269364000000001
# 1.3832223
# 1.4022782999999999
# 1.294028
# 1.3004452
# 1.34295555
# 1.3466311499999999
# 1.3935137499999999
# 1.44058925
# 40.58432165
# 1.3314243000000001
# 25.8114523
# 1.3131051
# 1.2990858
# 1.44565285
# 1.3865332
# 1.3702241
# 1.3749396
# 1.340467
# 1.3210897
# 1.4272654
# 1.35001895
# 1.334946
# 1.3465775500000001
# 1.3501232
# 1.3190814
# 1.2972322
# 1.36456
# 1.30983385
# 1.3494462
# 1.30755665
# 1.3083187
# 1.3830944
# 1.3196264
# 1.3163472999999999
# 1.39972215
# 1.30854205
# 1.38827575
# 1.35357275
# 1.3555729
# 1.42830325
# 1.436023
# 51.91635335
# 1.3725581999999998
# 1.3784798500000002
# 1.42793975
# 1.4326645500000001
# 1.3415819
# 1.3468879999999999
# 1.4071727
# 1.3570939499999999
# 1.3888414
# 1.3486042999999999

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(152,154):
    getLanlong(x)
# Out:
# 1.33744335
# 1.31531085

# %%
def getLanlong(i):
    subzone = schinfo_df.loc[i, 'Name']
    address = subzone
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(155,159):
    getLanlong(x)
# Out:
# 1.3171892
# 13.7983754
# 1.34386705
# 1.43640725

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                       school_name                            url_address  \
# 0        ADMIRALTY PRIMARY SCHOOL    http://www.admiraltypri.moe.edu.sg/
# 1      ADMIRALTY SECONDARY SCHOOL     http://www.admiraltysec.moe.edu.sg
# 2    AHMAD IBRAHIM PRIMARY SCHOOL  http://www.ahmadibrahimpri.moe.edu.sg
# 3  AHMAD IBRAHIM SECONDARY SCHOOL  http://www.ahmadibrahimsec.moe.edu.sg
# 4                  AI TONG SCHOOL           http://www.aitong.moe.edu.sg
#
#                    address  postal_code telephone_no telephone_no_2    fax_no  \
# 0    11   WOODLANDS CIRCLE       738907     63620598             na  63627512
# 1  31   WOODLANDS CRESCENT       737916     63651733       63654596  63652774
# 2    10   YISHUN STREET 11       768643     67592906             na  67592927
# 3     751  YISHUN AVENUE 7       768928     67585384             na  67557778
# 4   100  Bright Hill Drive       579646     64547672             na  64532726
#
#   fax_no_2            email_address           mrt_desc  \
# ...

# %%
# check
scinf_df.shape
# Out:
# (345, 35)

# %%
# get the columns names
scinf_df.columns
# Out:
# Index(['school_name', 'url_address', 'address', 'postal_code', 'telephone_no',
#        'telephone_no_2', 'fax_no', 'fax_no_2', 'email_address', 'mrt_desc',
#        'bus_desc', 'principal_name', 'first_vp_name', 'second_vp_name',
#        'third_vp_name', 'fourth_vp_name', 'fifth_vp_name', 'sixth_vp_name',
#        'visionstatement_desc', 'missionstatement_desc',
#        'philosophy_culture_ethos', 'dgp_code', 'zone_code', 'type_code',
#        'nature_code', 'session_code', 'mainlevel_code', 'sap_ind',
#        'autonomous_ind', 'gifted_ind', 'ip_ind', 'mothertongue1_code',
#        'mothertongue2_code', 'mothertongue3_code', 'special_sdp_offered'],
#       dtype='object')

# %%
# get wanted columns
scinf2_df = scinf_df[['school_name','postal_code','mainlevel_code']]

# view
scinf2_df.head()
# Out:
#                       school_name  postal_code mainlevel_code
# 0        ADMIRALTY PRIMARY SCHOOL       738907        PRIMARY
# 1      ADMIRALTY SECONDARY SCHOOL       737916      SECONDARY
# 2    AHMAD IBRAHIM PRIMARY SCHOOL       768643        PRIMARY
# 3  AHMAD IBRAHIM SECONDARY SCHOOL       768928      SECONDARY
# 4                  AI TONG SCHOOL       579646        PRIMARY

# %%
# check
scinf2_df.shape
# Out:
# (345, 3)

# %%
# counts the number of different levels
scinf2_df['mainlevel_code'].value_counts()
# Out:
# PRIMARY                  181
# SECONDARY                138
# MIXED LEVELS              14
# JUNIOR COLLEGE            10
# na                         1
# CENTRALISED INSTITUTE      1
# Name: mainlevel_code, dtype: int64

# %%
# store the rows with Education Level that are "Primary" 
level_na = scinf2_df[scinf2_df.mainlevel_code == 'PRIMARY']

# use the drop method to delete the rows 
scinf2_df.drop(level_na.index, inplace=True)

# counts the number of different levels again
scinf2_df['mainlevel_code'].value_counts()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# SECONDARY                138
# MIXED LEVELS              14
# JUNIOR COLLEGE            10
# na                         1
# CENTRALISED INSTITUTE      1
# Name: mainlevel_code, dtype: int64

# %%
# check
scinf2_df.dtypes
# Out:
# school_name       object
# postal_code        int64
# mainlevel_code    object
# dtype: object

# %%
# add " .SG" to postal codes to be recognised
scinf2_df['postal_code'] = scinf2_df['postal_code'].astype(str) + ', SG'

# reset index from 0
scinf2_df.reset_index(drop=True, inplace=True)

# view
scinf2_df.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                          school_name postal_code  mainlevel_code
# 0         ADMIRALTY SECONDARY SCHOOL  737916, SG       SECONDARY
# 1     AHMAD IBRAHIM SECONDARY SCHOOL  768928, SG       SECONDARY
# 2          ANDERSON SECONDARY SCHOOL  569206, SG       SECONDARY
# 3  ANDERSON SERANGOON JUNIOR COLLEGE  569843, SG  JUNIOR COLLEGE
# 4        ANG MO KIO SECONDARY SCHOOL  569362, SG       SECONDARY

# %%
# check
scinf2_df.dtypes
# Out:
# school_name       object
# postal_code       object
# mainlevel_code    object
# dtype: object

# %% [markdown]
# Use the function to get coordinates

# %% [markdown]
# Latitudes first

# %%
# get latitude from index 0 to 8
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(9):
    getLanlong(x)
# Out:
# 1.4459601684991499
# 1.4360703465893339
# 1.3750884124643885
# 1.3787495689535247
# 1.367769507530756
# 1.3304074092409928
# 1.3027642104786328
# 1.3197001585579067
# 1.3030748622509605

# %%
# get latitude from index 10 to 32
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(10,33):
    getLanlong(x)
# Out:
# 1.3701444860163359
# 1.340398871219019
# 1.3415218272226206
# 1.334235892773273
# 1.3254084685979726
# 1.324922948801112
# 1.324495426396647
# 1.3427439313250527
# 1.37071333263833
# 1.3073400383996356
# 1.3484520598521583
# 1.2859405065818954
# 1.38208420390674
# 1.3457423973685223
# 1.453675869222346
# 1.3547465277906723
# 1.325220475388485
# 1.3346136804879882
# 1.3404410136440361
# 1.3065439112175976
# 1.3324473883672654
# 1.3918737861840091
# 1.3737202484770445

# %%
# get latitude from index 34 to 99
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(34,100):
    getLanlong(x)
# Out:
# 1.4266389507245019
# 1.3833672300341955
# 1.3054464908001535
# 1.4190460401012197
# 1.3154376638869254
# 1.3196436319845222
# 1.3965659322902995
# 1.2935376111819035
# 1.3435554583448717
# 1.3374116361844677
# 1.3667850469708402
# 1.363625077204759
# 13.7804133
# 1.3611864404636387
# 1.3567263772062723
# 1.4002275117692458
# 13.7804133
# 1.4416382265735272
# 1.3016339623100874
# 1.3750310118783073
# 13.7804133
# 1.3471857316272127
# 1.2895748944692715
# 1.3175340026674336
# 1.3977011643617656
# 1.3824407749508056
# 1.3447401554692437
# 1.3745799087232755
# 1.3532234869667825
# 1.3716493108647063
# 1.3779296315614122
# 1.3520898915248165
# 1.3258125697821077
# 1.3531531253376252
# 1.3852918507713392
# 1.3304471958605528
# 1.335599163007713
# 1.3517962433853623
# 13.7804133
# 1.3011426201311613
# 1.3905156384964787
# 1.3502652164677604
# 1.3665085649932776
# 1.327592393206182
# 1.3419569550955661
# 1.4374527129984056
# 1.3687560538588437
# 1.3675957201578233
# 1.3328188602272428
# ...

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(100,159):
    getLanlong(x)
# Out:
# 1.3727947474141566
# 1.3543514826415386
# 1.3504937022917098
# 1.3907598277591982
# 1.3594526402529636
# 1.3664309716516334
# 1.3271250221653506
# 1.3825576842310627
# 1.402285123434729
# 1.2933952063881953
# 1.300288229858127
# 1.3428497252095244
# 1.3464972429346227
# 1.3934743481274432
# 1.3434657455370247
# 1.4410673906932965
# 1.3131903212438998
# 1.299371680417444
# 1.4456613714095263
# 1.38644233373961
# 1.370049902208315
# 1.3748851161877373
# 1.3211087775054113
# 1.4271254249104663
# 1.4365477133738909
# 1.3502456062815305
# 1.3325672049589024
# 1.3309799009459526
# 1.3349427986600402
# 1.3468475061787317
# 1.3500563884618355
# 13.7804133
# 1.3199605308805102
# 1.3086348378784836
# 1.3645722367704864
# 1.3762048689325195
# 1.349460895852039
# 1.3099091938647818
# 1.307862969859482
# 1.3083887940326473
# 1.3831583613322187
# 1.3183891547479452
# 1.316258254180036
# 1.3997921949177121
# 1.3059926883477881
# 1.3085420786565487
# 1.3881184312573709
# 1.3535777962615294
# ...

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(latitude))
    
for x in range(160,164):
    getLanlong(x)
# Out:
# 1.3427899647918569
# 1.3571495734094283
# 1.3889874252535928
# 1.3487129750055373

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(longitude))
    
for x in range(9):
    getLanlong(x)
# Out:
# 103.80278481638744
# 103.83014981269604
# 103.85159449486005
# 103.84591077800243
# 103.8425200660313
# 103.94145827956677
# 103.78568186563996
# 103.83564544302268
# 103.7804261897334

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(longitude))
    
for x in range(10,33):
    getLanlong(x)
# Out:
# 103.76628175691204
# 103.88247145930853
# 103.85223340189889
# 103.9354606561389
# 103.95109649183881
# 103.94348424059442
# 103.86049389232092
# 103.70167813123327
# 103.87757742043284
# 103.88690708725129
# 103.74052625326601
# 103.81313325740106
# 103.73832877283755
# 103.75223004898888
# 103.81418604520815
# 103.8450965448183
# 103.83550094063165
# 103.87428293462871
# 103.95306634653026
# 103.91774005098937
# 103.84279297079837
# 103.90250272898551
# 103.83409591046555

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(longitude))
    
for x in range(34,100):
    getLanlong(x)
# Out:
# 103.79313198768408
# 103.75151614702317
# 103.89175795438874
# 103.837173321055
# 103.76200612766212
# 103.74571724929994
# 103.90025912810842
# 103.81777083610685
# 103.74275894341118
# 103.92688619510925
# 103.85218710147396
# 103.74459422265527
# 121.05223275706865
# 103.95601637870433
# 103.96093151554186
# 103.90235814928766
# 121.05223275706865
# 103.79396953673856
# 103.78450365350604
# 103.76404434122692
# 121.05223275706865
# 103.72471030373609
# 103.8237157842034
# 103.88324015508223
# 103.91160195495179
# 103.77387665561933
# 103.84999947070737
# 103.95516152654652
# 103.75305827300006
# 103.89573170799721
# 103.88234255504483
# 103.72162538195482
# 103.8040985819149
# 103.93355040161921
# 103.7540187149258
# 103.72401801132285
# 103.70244020437808
# 103.7290915681291
# 121.05223275706865
# 103.76512990879175
# 103.74116760887684
# 103.85467401173537
# 103.95745170741378
# 103.90166887275605
# 103.87827183230323
# 103.77596715467882
# 103.83563582696364
# ...

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(longitude))
    
for x in range(100,159):
    getLanlong(x)
# Out:
# 103.95975524325456
# 103.94851872049976
# 103.88547015364747
# 103.87826408529364
# 103.87068496299109
# 103.82975556212045
# 103.92087617865718
# 103.84273879893162
# 103.90906524103286
# 103.81310037326789
# 103.80199702910174
# 103.84315445608512
# 103.84355535413945
# 103.75099518569269
# 103.70930180242658
# 103.78811932235261
# 103.77379140111427
# 103.84873833438131
# 103.81665950126592
# 103.89866059255505
# 103.86901081787859
# 103.90205932097436
# 103.82818076919756
# 103.78865303115789
# 103.80430917768686
# 103.93004380261759
# 103.86352968400863
# 103.86601134040109
# 103.94220316676633
# 103.87553647635495
# 103.93707897977541
# 121.05223275706865
# 103.8096717812436
# 103.91695000959184
# 103.75043472045702
# 103.93787719581569
# 103.94410950664493
# 103.75797707490068
# 103.89622270714382
# 103.89727481287686
# 103.75518944488292
# 103.93510446192266
# 103.94757610857532
# 103.74594661845522
# 103.9198819118414
# 103.92745781692149
# 103.75994639175941
# ...

# %%
def getLanlong(i):
    postCode = scinf2_df.loc[i, 'postal_code']
    address = postCode
    geolocator = Nominatim(user_agent="sg_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('{}'.format(longitude))
    
for x in range(160,164):
    getLanlong(x)
# Out:
# 103.76005139573589
# 103.89072172935616
# 103.76527683024429
# 103.86950289605103

# %%
# get coordinates for schools which does not have (correct) coordinates
# ASSUMPTION ENGLISH SCHOOL

address = "ASSUMPTION ENGLISH SCHOOL, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.3690319,103.76654418546404

# %%
# get coordinates for schools which does not have (correct) coordinates
# CHIJ ST. THERESA'S CONVENT

address = "CHIJ ST. THERESA'S CONVENT, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.27614885,103.8222529475166

# %%
# get coordinates for schools which does not have (correct) coordinates
# EUNOIA JUNIOR COLLEGE

address = "EUNOIA JUNIOR COLLEGE, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.3139802,103.78697898912887

# %%
# get coordinates for schools which does not have (correct) coordinates
# FUCHUN SECONDARY SCHOOL

address = "FUCHUN SECONDARY SCHOOL, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.43072245,103.77729137149447

# %%
# get coordinates for schools which does not have (correct) coordinates
# NATIONAL JUNIOR COLLEGE

address = "NATIONAL JUNIOR COLLEGE, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.330727,103.80441667162106

# %%
# get coordinates for schools which does not have (correct) coordinates
# NUS HIGH SCHOOL OF MATHEMATICS AND SCIENCE

address = "NUS HIGH SCHOOL OF MATHEMATICS AND SCIENCE, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.3069962,103.76999563920836

# %%
# get coordinates for schools which does not have (correct) coordinates
# ST. JOSEPH'S INSTITUTION

address = "ST. JOSEPH'S INSTITUTION, SG"

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('{},{}'.format(latitude, longitude))
# Out:
# 1.2972322,103.85110097332364

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)

# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for lat, lng, label in zip(schcor_df['Latitude'], schcor_df['Longitude'],schcor_df['School Name']):
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        [lat, lng],
        radius=3.5,
        popup=label,
        color='crimson',
        fill= True,
        fill_color='pink',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)
    
    
map_singapore
# Out:
# [1.357107, 103.8194992]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We are done getting school coordinates, which are combined into a csv file offsite in excel.

# %%
body = client_6501c7ad58044483ae667dff4bd240be.get_object(Bucket='thebattleofneighborhoodpart3-donotdelete-pr-unxqpxo0pneoix',Key='SchoolLatLong.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# name the data
schcor_df = pd.read_csv(body)

# view
schcor_df.head()
# Out:
#                          School Name  Latitude   Longitude
# 0         ADMIRALTY SECONDARY SCHOOL  1.445960  103.802785
# 1     AHMAD IBRAHIM SECONDARY SCHOOL  1.436070  103.830150
# 2          ANDERSON SECONDARY SCHOOL  1.375088  103.851594
# 3  ANDERSON SERANGOON JUNIOR COLLEGE  1.378750  103.845911
# 4        ANG MO KIO SECONDARY SCHOOL  1.367770  103.842520

# %%
# check
schcor_df.shape
# Out:
# (164, 3)

# %%
import folium

# %%
latitude_na = schcor_df[schcor_df['Latitude'] >= 2].index
schcor_df.drop(latitude_na, inplace=True)
schcor_df.shape
# Out:
# (162, 3)

# %%
address = 'Singapore, SG'

geolocator = Nominatim(user_agent="sg_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of Singapore are {}. {}.'.format(latitude, longitude))
# Out:
# The geographical coordinate of Singapore are 1.357107. 103.8194992.

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)

# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for lat, lng, label in zip(schcor_df['Latitude'], schcor_df['Longitude'],schcor_df['School Name']):
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        [lat, lng],
        radius=2.5,
        popup=label,
        color='blue',
        fill= True,
        fill_color='#2E7D32',
        fill_opacity=0.5,
        parse_html=False).add_to(map_singapore)
    
    
map_singapore
# Out:
# [1.357107, 103.8194992]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)

# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for lat, lng, label in zip(schcor_df['Latitude'], schcor_df['Longitude'],schcor_df['School Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3.5,
        popup=label,
        color='steelblue',
        fill= True,
        fill_color='lightblue',
        fill_opacity=0.6,
        parse_html=False).add_to(map_singapore)
    
    
map_singapore
# Out:
# [1.3509859, 103.84825507492937]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
body = client_6501c7ad58044483ae667dff4bd240be.get_object(Bucket='thebattleofneighborhoodpart3-donotdelete-pr-unxqpxo0pneoix',Key='Planning Area laglon.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
Sgtc_f = pd.read_csv(body)
Sgtc_f.head()
# Out:
#   Planning Area  Latitude   Longitude
# 0    Ang Mo Kio  1.370073  103.849516
# 1         Bedok  1.323976  103.930216
# 2        Bishan  1.350986  103.848255
# 3   Bukit Batok  1.349057  103.749591
# 4   Bukit Merah  1.270439  103.828318

# %%
# use request.get to send a GET request to the specified url
url = "https://en.wikipedia.org/wiki/Planning_Areas_of_Singapore"

r = requests.get(url)

# get content from website and store in a variable
singapore_html = BeautifulSoup(r.content)

# store all the strings in the html page in variable "soup"
soup = BeautifulSoup(str(singapore_html))

# %%
# use find "table", the second table on the website
plarea_tb = soup.find_all('table')[1]

# extract the charaters from the table
table_str = str(plarea_tb.extract())

# read the table into panda dataframe
singapore_df = pd.read_html(table_str)[0]

# display the first five rows of table 
singapore_df.head()
# Out:
#   Name (English) Malay Chinese         Pinyin              Tamil      Region  \
# 0     Ang Mo Kio   NaN     宏茂桥  Hóng mào qiáo        ஆங் மோ கியோ  North-East
# 1          Bedok     *      勿洛         Wù luò             பிடோக்        East
# 2         Bishan   NaN      碧山        Bì shān             பீஷான்     Central
# 3       Boon Lay   NaN      文礼         Wén lǐ            பூன் லே        West
# 4    Bukit Batok     *    武吉巴督     Wǔjí bā dū  புக்கிட் பாத்தோக்        West
#
#    Area (km2) Population[7] Density (/km2)
# 0       13.94        163950          13400
# 1       21.69        279380          13000
# 2        7.62         88010          12000
# 3        8.23            30            3.6
# 4       11.13        153740          14000

# %%
plare_df = singapore_df[['Name (English)', 'Density (/km2)']]

plare_df.head()
# Out:
#   Name (English) Density (/km2)
# 0     Ang Mo Kio          13400
# 1          Bedok          13000
# 2         Bishan          12000
# 3       Boon Lay            3.6
# 4    Bukit Batok          14000

# %%
# rename the columns
plare2_df = plare_df.rename(columns={"Name (English)": "Planning Area"})

# display the change
plare2_df.head()
# Out:
#   Planning Area Density (/km2)
# 0    Ang Mo Kio          13400
# 1         Bedok          13000
# 2        Bishan          12000
# 3      Boon Lay            3.6
# 4   Bukit Batok          14000

# %%
plare3_df = pd.merge(plare2_df, Sgtc_f, on="Planning Area")

plare3_df.head()
# Out:
#   Planning Area Density (/km2)  Latitude   Longitude
# 0    Ang Mo Kio          13400  1.370073  103.849516
# 1         Bedok          13000  1.323976  103.930216
# 2        Bishan          12000  1.350986  103.848255
# 3   Bukit Batok          14000  1.349057  103.749591
# 4   Bukit Merah          11000  1.270439  103.828318

# %%
plare3_df.shape
# Out:
# (28, 4)

# %%
plare3_df.dtypes
# Out:
# Planning Area      object
# Density (/km2)     object
# Latitude          float64
# Longitude         float64
# dtype: object

# %%
plare3_df['Density (/km2)'] = pd.to_numeric(plare3_df["Density (/km2)"])

plare3_df.astype({'Density (/km2)': 'float64'}).dtypes
# Out:
# Planning Area      object
# Density (/km2)    float64
# Latitude          float64
# Longitude         float64
# dtype: object

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)


# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for i in range(0, 28):
    json.dumps(str(plare3_df.loc[i]['Density (/km2)']))
    folium.CircleMarker(
      location=[plare3_df.loc[i]['Latitude'], plare3_df.loc[i]['Longitude']],
      popup=plare3_df.loc[i]['Planning Area'],
      radius=plare3_df.loc[i]['Density (/km2)']*0.001,
      color='steelblue',
      fill=True,
      fill_color='steelblue',
      fill_opacity=0.7
   ).add_to(map_singapore)

    
map_singapore
# Out:
# [1.3509859, 103.84825507492937]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)

# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for lat, lng, label in zip(plare3_df['Latitude'], plare3_df['Longitude'],plare3_df['Planning Area']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='steelblue',
        fill= True,
        fill_color='lightblue',
        fill_opacity=0.7,
        parse_html=False).add_to(map_singapore)
    

    
map_singapore
# Out:
# [1.357107, 103.8194992]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Import csv file for map generation store it under the variable nsch_df

# %%
nsch_df = pd.read_csv("DF8_Number of Schools.csv", dtype=str)
nsch_df.head()
# Out:
#   Planning Area Density of Student Population(/km2)  \
# 0    Ang Mo Kio                   753.2281205164992
# 1         Bedok                   885.2005532503458
# 2        Bishan                   734.9081364829398
# 3   Bukit Batok                    934.411500449236
# 4   Bukit Merah                   529.9860529986054
#
#   Density of Population(/km2)  \
# 0          12537.302725968435
# 1          13358.690640848316
# 2          11902.887139107612
# 3          12513.027852650494
# 4          10867.503486750351
#
#                                                 Name Number of Schools
# 0  Anderson Secondary School,Ang Mo Kio Secondary...                 8
# 1  Anglican High School,Bedok Green Secondary Sch...                12
# 2  Catholic High School,Guangyang Secondary Schoo...                 7
# 3  Bukit Batok Secondary School,Bukit View Second...                 5
# 4  Bukit Merah Secondary School,CHIJ St. Theresa'...                 4

# %%
nsch_df.shape
# Out:
# (27, 5)

# %% [markdown]
# ### Combine nsch_df with Sgtc_f for coordinates data and "store" it under the variable "nsll_df"

# %%
nsll_df = pd.merge(nsch_df, Sgtc_f, on = "Planning Area")
nsll_df.head()
# Out:
#   Planning Area  Density of Student Population(/km2)  \
# 0    Ang Mo Kio                           753.228121
# 1         Bedok                           885.200553
# 2        Bishan                           734.908136
# 3   Bukit Batok                           934.411500
# 4   Bukit Merah                           529.986053
#
#    Density of Population(/km2)  \
# 0                 12537.302726
# 1                 13358.690641
# 2                 11902.887139
# 3                 12513.027853
# 4                 10867.503487
#
#                                                 Name  Number of Schools  \
# 0  Anderson Secondary School,Ang Mo Kio Secondary...                  8
# 1  Anglican High School,Bedok Green Secondary Sch...                 12
# 2  Catholic High School,Guangyang Secondary Schoo...                  7
# 3  Bukit Batok Secondary School,Bukit View Second...                  5
# 4  Bukit Merah Secondary School,CHIJ St. Theresa'...                  4
#
# ...

# %%
nsll_df.shape
# Out:
# (27, 7)

# %% [markdown]
# ### Check and change datatypes if necessary, in preparation for map creation with folium

# %%
nsll_df.dtypes
# Out:
# Planning Area                           object
# Density of Student Population(/km2)    float64
# Density of Population(/km2)            float64
# Name                                    object
# Number of Schools                        int64
# Latitude                               float64
# Longitude                              float64
# dtype: object

# %%
nsll_df.astype({'Number of Schools': 'float64'}).dtypes
# Out:
# Planning Area                           object
# Density of Student Population(/km2)    float64
# Density of Population(/km2)            float64
# Name                                    object
# Number of Schools                      float64
# Latitude                               float64
# Longitude                              float64
# dtype: object

# %%
nsll_df.head()
# Out:
#   Planning Area  Density of Student Population(/km2)  \
# 0    Ang Mo Kio                           753.228121
# 1         Bedok                           885.200553
# 2        Bishan                           734.908136
# 3   Bukit Batok                           934.411500
# 4   Bukit Merah                           529.986053
#
#    Density of Population(/km2)  \
# 0                 12537.302726
# 1                 13358.690641
# 2                 11902.887139
# 3                 12513.027853
# 4                 10867.503487
#
#                                                 Name  Number of Schools  \
# 0  Anderson Secondary School,Ang Mo Kio Secondary...                  8
# 1  Anglican High School,Bedok Green Secondary Sch...                 12
# 2  Catholic High School,Guangyang Secondary Schoo...                  7
# 3  Bukit Batok Secondary School,Bukit View Second...                  5
# 4  Bukit Merah Secondary School,CHIJ St. Theresa'...                  4
#
# ...

# %% [markdown]
# ### Map generation with folium, the use circle markers, whose radii are directly proportional to the number of schools. Tiles with "Open Street Map", Zoom start with 10.5.

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)
# Out:
# [1.3509859, 103.84825507492937]

# %%
# store the Singapore's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)


# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5)

# add markers to map
for i in range(0, 27):
    size = int(nsll_df['Number of Schools'].iloc[i])*2
    folium.CircleMarker(
      location=[nsll_df.loc[i]['Latitude'], nsll_df.loc[i]['Longitude']],
      popup=nsll_df.loc[i]['Planning Area'],
      radius=size,
      coloar='steelblue',
      fill=True,
      fill_color='steelblue',
      fill_opacity=0.7
   ).add_to(map_singapore)

    
map_singapore
# Out:
# [1.3509859, 103.84825507492937]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Map generation with folium, the use circle markers, whose radii are directly proportional to Density of Population in 2015. Tiles with "Open Street Map", Zoom start with 10.5.

# %%
# store the Toronto's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)


# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for i in range(0, 27):
    json.dumps(str(nsll_df.loc[i]['Density of Population(/km2)']))
    folium.CircleMarker(
      location=[nsll_df.loc[i]['Latitude'], nsll_df.loc[i]['Longitude']],
      popup=nsll_df.loc[i]['Planning Area'],
      radius=nsll_df.loc[i]['Density of Population(/km2)']*0.001,
      coloar='steelblue',
      fill=True,
      fill_color='steelblue',
      fill_opacity=0.7
   ).add_to(map_singapore)

    
map_singapore
# Out:
# [1.3509859, 103.84825507492937]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Map generation with folium, the use circle markers, whose radii are directly proportional to Density of Student Population in 2015. Tiles with "Open Street Map", Zoom start with 10.5.

# %%
# store the Toronto's latitude and longitude info
singapore_latlong = [latitude, longitude]
print(singapore_latlong)


# use folium library to create a map of Toronto using latitude
# and longitude values
map_singapore = folium.Map(location=singapore_latlong, tiles="OpenStreetMap", zoom_start=10.5
                    )

# add markers to map
for i in range(0, 27):
    json.dumps(str(nsll_df.loc[i]['Density of Student Population(/km2)']))
    folium.CircleMarker(
      location=[nsll_df.loc[i]['Latitude'], nsll_df.loc[i]['Longitude']],
      popup=nsll_df.loc[i]['Planning Area'],
      radius=nsll_df.loc[i]['Density of Student Population(/km2)']*0.015,
      coloar='steelblue',
      fill=True,
      fill_color='steelblue',
      fill_opacity=0.7
   ).add_to(map_singapore)

    
map_singapore
# Out:
# [1.3509859, 103.84825507492937]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
